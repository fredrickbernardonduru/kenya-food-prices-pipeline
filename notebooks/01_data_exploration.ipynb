# %%
import pandas as pd

df = pd.read_csv("../data/sample_food_prices.csv")

df.head()
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17994 entries, 0 to 17993
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          17994 non-null  object
#  1   admin1        17947 non-null  object
#  2   admin2        17947 non-null  object
#  3   market        17994 non-null  object
#  4   market_id     17994 non-null  int64
#  5   latitude      17947 non-null  float64
#  6   longitude     17947 non-null  float64
#  7   category      17994 non-null  object
#  8   commodity     17994 non-null  object
#  9   commodity_id  17994 non-null  int64
#  10  unit          17994 non-null  object
#  11  priceflag     17994 non-null  object
#  12  pricetype     17994 non-null  object
#  13  currency      17994 non-null  object
#  14  price         17994 non-null  float64
#  15  usdprice      17994 non-null  float64
# dtypes: float64(4), int64(2), object(10)
# memory usage: 2.2+ MB
#           market_id      latitude     longitude  commodity_id         price  \
# count  17994.000000  17947.000000  17947.000000  17994.000000  17994.000000
# mean    4003.816883      0.702996     36.982707    295.778593   1340.830652
# std     3151.854784      2.297599      2.023904    294.982271   2594.920122
# min      184.000000     -4.660000     34.360000     50.000000      5.000000
# 25%     1850.000000     -1.270000     34.850000     67.000000     67.707500
# 50%     3254.000000      0.280000     36.780000    148.000000    135.630000
# 75%     5670.000000      3.390000     38.780000    440.000000   1231.110000
# max    10509.000000      4.620000     41.860000    937.000000  19800.000000
#
#            usdprice
# count  17994.000000
# mean      12.299793
# std       23.105145
# min        0.039000
# 25%        0.600000
# 50%        1.060000
# 75%       11.887500
# max      184.820000

# %%
df["date"] = pd.to_datetime(df["date"])

# %%
df = df.dropna(subset=["admin1", "admin2", "latitude", "longitude"])

# %%
df["commodity"].value_counts().head(20)
# Out:
# commodity
# Beans (dry)                   1217
# Maize (white)                 1161
# Maize                         1085
# Beans                         1039
# Potatoes (Irish)               929
# Sugar                          929
# Salt                           847
# Wheat flour                    778
# Sorghum                        696
# Rice (aromatic)                606
# Oil (vegetable)                585
# Maize (white, dry)             574
# Milk (cow, pasteurized)        515
# Kale                           491
# Maize flour                    471
# Oil (vegetable, fortified)     458
# Maize flour (white)            440
# Milk (UHT)                     400
# Rice                           381
# Bananas                        354
# Name: count, dtype: int64

# %%
df["commodity"] = df["commodity"].str.strip().str.title()

# %%
df["market"].nunique()
# Out:
# 224

# %%
df["market"].value_counts()
# Out:
# market
# Nairobi                       1198
# Eldoret town (Uasin Gishu)    1001
# Kisumu                         685
# Kakuma 3                       481
# Mombasa                        465
#                               ...
# Suq Jini                         3
# Kaembeni                         3
# Vanga (Kwale)                    3
# Kotile                           2
# Sololo                           1
# Name: count, Length: 224, dtype: int64

# %%
df["market"] = df["market"].str.strip().str.title()

# %%
df["currency"].value_counts()
# Out:
# currency
# KES    17947
# Name: count, dtype: int64

# %%
df["admin1"] = df["admin1"].str.strip().str.title()
df["admin2"] = df["admin2"].str.strip().str.title()

# %%
df["year"] = df["date"].dt.year
df["month"] = df["date"].dt.month
